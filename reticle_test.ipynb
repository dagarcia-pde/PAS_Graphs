# %%
import pandas as pd
import PyUber

# %%
imo_source='D1D_PROD_XEUS_CENTRAL'
imo_fab_list="'F32','F42','F12','F22','F52'"

# %%
conn =  PyUber.connect(datasource= imo_source)

# %%
fab_prod = '8PWNCVB'
ret_name = '8PWNCB'

# %%
query = f'''
    SELECT 
        z0.commonname AS common_name
        ,z0.title AS title
        ,'{fab_prod}' AS FAB_PROD
        ,z0.product AS RET_PROD
        ,z0.rev AS rev
        ,z0.layer AS layer
        ,z0.step AS step
        ,z0.platetype AS plate_type
        ,z0.tapeintrend AS tapein_trend
        ,z0.itotrend AS ito_trend
        ,To_Char(z0.itocommit,'yyyy-mm-dd hh24:mi:ss') AS ito_commit
        ,z0.itostatus AS ito_status
        ,z0.retfabrev AS ret_fabrev
        ,z0.fab AS fab
        ,z0.barcode AS barcode
        ,z0.imotrend AS imo_trend
        ,To_Char(z0.imocommit,'yyyy-mm-dd hh24:mi:ss') AS imo_commit
        ,z0.imostatus AS imo_status
        ,To_Char(z0.shipdate,'yyyy-mm-dd hh24:mi:ss') AS shipdate
        ,z0.fabrequireddate AS fab_requireddate
        ,z0.imodotprocess AS imo_dotprocess
        ,z0.imoishot AS imo_ishot
        ,z0.technology AS technology
        ,z0.toengcontact AS to_engcontact
        ,z0.dbnames AS dbnames
        ,To_Char(z0.last_updated_timestamp,'yyyy-mm-dd hh24:mi:ss') AS last_updated_timestamp
    FROM 
        F_IMO_TRIFECTA_DASHBOARD z0
    WHERE
        1=1
        --AND z0.last_updated_timestamp >= SYSDATE - 180 
        AND z0.fab In ({imo_fab_list})     
        AND (
            z0.product LIKE '{ret_name}'
        )
'''

# %%
df = pd.read_sql(query, conn)
# Out:
# C:\Users\dagarcia\AppData\Local\Temp\ipykernel_66224\1168034203.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
df
# Out:
#             COMMON_NAME TITLE  FAB_PROD RET_PROD REV LAYER STEP PLATE_TYPE  \
# 0   PANTHERLAKECPU-UDIE  0AB4  8PXMCVAG   8PXMCG   0   DR6    G       AI6N
# 1   PANTHERLAKECPU-UDIE  0AA4  8PXMCVAG   8PXMCG   0   NDR    G       AI6N
# 2   PANTHERLAKECPU-UDIE  0AA3  8PXMCVAG   8PXMCG   0   PDR    G       AI6N
# 3   PANTHERLAKECPU-UDIE  0AA4  8PXMCVAG   8PXMCG   0   PDR    G       AI6N
# 4   PANTHERLAKECPU-UDIE  0SA4  8PXMCVAG   8PXMCG   0   ZRO    G       XC6N
# ..                  ...   ...       ...      ...  ..   ...  ...        ...
# 70  PANTHERLAKECPU-UDIE  0AA4  8PXMCVAG   8PXMCG   0   DR5    G       AI6N
# 71  PANTHERLAKECPU-UDIE  0AB3  8PXMCVAG   8PXMCG   0   DR6    G       AI6N
# 72  PANTHERLAKECPU-UDIE  0AB2  8PXMCVAG   8PXMCG   0   NBM    G       AI6N
# 73  PANTHERLAKECPU-UDIE  0AB2  8PXMCVAG   8PXMCG   0   PB2    G       AI6N
# 74  PANTHERLAKECPU-UDIE  0AB2  8PXMCVAG   8PXMCG   0   PBM    G       AI6N
#
#    TAPEIN_TREND   ITO_TREND  ...           IMO_COMMIT           IMO_STATUS  \
# 0    05/22/2025  05/28/2025  ...  2025-07-19 00:00:00  Processing - Active
# 1    12/09/2024  12/11/2024  ...  2025-07-12 00:00:00              Shipped
# 2    12/09/2024  12/11/2024  ...  2025-07-12 00:00:00              Shipped
# 3    12/09/2024  12/11/2024  ...  2025-07-12 00:00:00              Shipped
# 4    12/09/2024  12/11/2024  ...  2025-07-12 00:00:00              Shipped
# ..          ...         ...  ...                  ...                  ...
# 70   12/09/2024  12/11/2024  ...  2025-07-19 00:00:00              Shipped
# 71   05/22/2025  05/28/2025  ...  2025-07-19 00:00:00              Shipped
# 72   07/02/2025  07/03/2025  ...  2025-08-20 00:00:00  Processing - Active
# 73   07/02/2025  07/03/2025  ...  2025-08-20 00:00:00  Processing - Active
# 74   07/02/2025  07/03/2025  ...  2025-08-20 00:00:00  Processing - Active
#
#                SHIPDATE FAB_REQUIREDDATE IMO_DOTPROCESS IMO_ISHOT TECHNOLOGY  \
# 0                  None       07/23/2025      1278.3-17      None     1278.3
# 1   2025-06-20 06:05:59       07/07/2025      1278.3-17      None     1278.3
# 2   2025-06-24 09:50:14       07/08/2025      1278.3-17      None     1278.3
# 3   2025-06-28 01:32:12       07/08/2025      1278.3-17      None     1278.3
# 4   2025-06-27 14:26:51       07/06/2025      1278.3-17      None     1278.3
# ..                  ...              ...            ...       ...        ...
# 70  2025-07-13 22:05:11       07/21/2025      1278.3-17      None     1278.3
# 71  2025-07-08 06:30:48       07/23/2025      1278.3-17      None     1278.3
# 72                 None       07/31/2025      1278.3-17      None     1278.3
# 73                 None       07/31/2025      1278.3-17      None     1278.3
# 74                 None       07/31/2025      1278.3-17      None     1278.3
#
#    TO_ENGCONTACT                    DBNAMES LAST_UPDATED_TIMESTAMP
# 0       REILLYCO  8pxmcg_0a.oas,f300288.oas    2025-05-28 10:44:01
# 1        DMJACOB  8pxmcg_0a.oas,f300288.oas    2025-05-01 05:31:53
# 2        DMJACOB  8pxmcg_0a.oas,f300288.oas    2025-05-01 05:15:45
# 3        DMJACOB  8pxmcg_0a.oas,f300288.oas    2025-05-01 05:15:45
# 4        DMJACOB  8pxmcg_0a.oas,f300288.oas    2025-05-01 05:31:53
# ..           ...                        ...                    ...
# 70       DMJACOB  8pxmcg_0a.oas,f300288.oas    2025-05-01 06:44:19
# 71      REILLYCO  8pxmcg_0a.oas,f300288.oas    2025-05-28 10:44:01
# 72       KSHARMA  8pxmcg_0a.oas,f300288.oas    2025-07-03 07:24:03
# 73       KSHARMA  8pxmcg_0a.oas,f300288.oas    2025-07-03 07:24:03
# 74       KSHARMA  8pxmcg_0a.oas,f300288.oas    2025-07-03 07:24:03
#
# [75 rows x 26 columns]
